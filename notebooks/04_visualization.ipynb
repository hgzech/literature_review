# %%
# default_exp visualization

# %% [markdown]
# # Review
#
# > API details.

# %%
#hide
from nbdev.showdoc import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
#export
from literature_review.article import make_articles
import pandas as pd

# %%
articles = make_articles('../data/interim/article_dicts/')

# %% [markdown]
# ## Pubmed search
# (("approach-avoidance task") OR ("approach-avoidance tendency") OR ("approach-avoidance bias") OR ("approach-avoidance conflict") OR ("approach tendency") OR ("approach bias"))
#
# > Yielded 541 Results

# %% [markdown]
# ## Selecting AAT studies (based on abstract)
# > 239 actually used an AAT (note that different versions, e.g. joystick AAT, mouse AAT, SRC, fMRI AAT, etc. are included).

# %%
df = pd.DataFrame([dict(a) for a in articles])
df = pd.concat([df, pd.json_normalize(df['annotations'])], axis = 1)

# %%
df['AAT'] = (df.AAT==True) & (df.manikin != True)
df['AAT_uncertain'] = (df.AAT_uncertain==True) & (df.manikin != True)

# %% [markdown]
# more than half of the studies did not use an AAT

# %%
df[df.reviewed==True].AAT.value_counts()
# Out:
# False    336
# True     205
# Name: AAT, dtype: int64

# %% [markdown]
# about a third of those were animal studies.

# %%
df.animal.value_counts()
# Out:
# False    446
# True      95
# Name: animal, dtype: int64

# %% [markdown]
# The articles that are in both uncertain categories should be checked.

# %% [markdown]
# about 10% were manikin SRC tasks.

# %%
df.manikin.value_counts()
# Out:
# True     44
# False    25
# Name: manikin, dtype: int64

# %% [markdown]
# ## Selecting studies that report reliability (based on fulltext)

# %% [markdown]
# ### Still uncertain

# %%
df[['AAT_uncertain','reliability_uncertain']].value_counts()
# Out:
# AAT_uncertain  reliability_uncertain
# False          False                    479
# True           False                     60
# False          True                       2
# dtype: int64

# %%
df[(df.AAT == True)]['reliability_uncertain'].value_counts()
# Out:
# False    204
# True       1
# Name: reliability_uncertain, dtype: int64

# %% [markdown]
# 36 of these were manikin AATs.

# %% [markdown]
# ### Split-half
# Note, that these are articles that mention split-half reliability in their text.  Of these some did not actually report split-half reliability of AAT approach-avoidance tendencies.

# %%
df[(df.AAT == True)]['split-half'].value_counts()
# Out:
# False    179
# True      26
# Name: split-half, dtype: int64

# %% [markdown]
# ### Retest
# Note that Reinecke did not show up in the initial pubmed search (not listed in pubmed).  Brown (2014) also did not show (does not show even when searching approach-avoidance task).

# %%
df[(df.AAT == True)].retest.value_counts()
# Out:
# False    200
# True       5
# Name: retest, dtype: int64

# %%
df[(df.AAT == True) & (df.retest == True)][['path','note']]
# Out:
#                                                 path  \
# 11   ../data/interim/article_dicts/Kahveci_2020.json
# 266    ../data/interim/article_dicts/Reddy_2016.json
# 291    ../data/interim/article_dicts/Rinck_2018.json
# 352   ../data/interim/article_dicts/Piercy_2021.json
# 414  ../data/interim/article_dicts/Peeters_2012.json
#
#                                                   note
# 11             rsb = .58 with 1000 bootstrapped splits
# 266                    not sure if they did split half
# 291  The internal consistency of the scores was low...
# 352
# 414  seems like this is a simple push minus pull di...

# %% [markdown]
# ### Both

# %%
df[(df.AAT == True)][['split-half','retest']].value_counts()
# Out:
# split-half  retest
# False       False     177
# True        False      23
#             True        3
# False       True        2
# dtype: int64

# %%
df[(df.AAT == True)]['split-half'].value_counts()
# Out:
# False    179
# True      26
# Name: split-half, dtype: int64

# %% [markdown]
# ## Retest reliabilities
# > Summary: Found two additional retest studies that both reported a retest reliabily of 0

# %% [markdown]
# ### Kahveci 2020
# > Reliability .23
#
# Lastly, we estimated the reliability of the current AAT. For this purpose, we used the bootstrapped split-half reliability functionality available in the AATtools package (Kahveci, 2019) for R (R Core Team, 2019). First, we performed 1000 random splits on the data. In each split, we excluded outlying trials and errors as we described in the methods section. Unlike in the Methods section, however, we did not exclude entire participants’ sessions if they had excessive error/outlier rates; if we did, the halved size of the samples would lead to the exclusion of a high number of participants. Next, we computed an approach bias score for each half of each split by subtracting the mean reaching time difference of approach-object and avoid-object trials from the mean reaching time difference between approach-food and avoid-food trials. We excluded participants in each half that had an approach bias score deviating more than 3 SD from the sample mean. We then computed the correlation between the two resulting approach bias scores for each participant. After obtaining 1000 such correlations, we computed the mean correlation coefficient and applied a Spearman-Brown correction to account for the halved test length, thereby obtaining a split-half reliability value that is not biased due to the arbitrariness of a single split, or due to outliers that disproportionately affect the correlation.
# <b>The split-half reliability of the full dataset (2 sessions per participant) was acceptable, (rSB = .58). When sessions were analyzed separately, reliability was lower (food-deprived rSB = .48, satiated rSB = .49). The test-retest reliability between food-deprived and satiated sessions was low (rretest = .23).</b>
# Using the same methodology as described above, we additionally computed the bootstrapped split-half reliability for raw pull and push reaction times for foods and objects, as well as reliabilities for push-pull difference scores for foods and objects separately. The reliabilities for single conditions were close to 1 (pull food: rSB = .98; push food: rSB = .99; pull objects: rSB = .97; push objects: rSB = .99) and the reliabilities for push-pull difference scores were also very high (push food – pull food: rSB = .95; push object – pull object: rSB = .89).

# %% [markdown]
# ### Reddy 2016
# > No control stimui in analysis

# %% [markdown]
# ### Peeters 2012
# > No control stimui in analysis

# %% [markdown]
# ### Rinck 2018
# > Reliability close to 0 at 1-year follow-up
#
# The internal consistency of these scores was determined by computing each participant’s AAT score for each picture and by computing Cronbach’s alpha for these values. The internal consistency of the scores was low but in the upper range of what is usually reported for RT tasks (Cronbach’s al- pha 􏱑 .58 for the pretest and .55 for the posttest). The retest reliability (computed for 143 patients in the no-training group only) was nonexistent, however (r 􏱑 .01, p 􏱑 .93). In addition, a change score (posttest minus pretest) was computed from these two scores. Negative values of this AAT change score indicate change in the intended direction, that is, a reduction of the alcohol ApB.

# %% [markdown]
# ### Piercy 2021
# > Reliability close to 0
#
# Internal consistency of the IR-
# AAT was calculated using the method reported by Kersbergen
# et al. (2015). The internal consistency was low (Cronbach’s α =
# 0.35 for alcohol-related items and 0.34 for non-alcohol-related
# items), and the test–retest reliability (calculated only for the
# 117 participants in the sham training control condition who
# completed both baseline and post-test AAT assessments in the
# larger RCT) was poor (r = 0.027, p = 0.774; see Manning et al.,
# 2021).

# %% [markdown]
# ## ToDo:
# ToDo: Mention that search was broad and there was not a lot, but now focus on more comparable tasks.; mention his pipeline
#
# If Maria's method does not change outline and is easy to implement, I can add it otherwise not.
#
# Add table for split-half
#
# Perhaps go animal route in introduction. (can be short)
# - then humans
# - then exponential increase (use review paper)
#
# Then broaden with discussion by introducing other tasks.

# %% [markdown]
# ## Notes

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df[df.note!=""][['path','note']])
# Out:
#                                                   path  \
# 0    ../data/interim/article_dicts/Bratti-van_der_W...
# 1        ../data/interim/article_dicts/Paige_2013.json
# 7    ../data/interim/article_dicts/Schumacher_2018....
# 12   ../data/interim/article_dicts/Wiesenfeller_202...
# 13      ../data/interim/article_dicts/Taylor_2012.json
# 14   ../data/interim/article_dicts/Wittekind_2015.json
# 15    ../data/interim/article_dicts/CHAMPION_1961.json
# 16   ../data/interim/article_dicts/Weidacker_2018.json
# 18     ../data/interim/article_dicts/Effting_2016.json
# 19     ../data/interim/article_dicts/WALTERS_1963.json
# 24   ../data/interim/article_dicts/de_la_Asuncion_2...
# 29    ../data/interim/article_dicts/Veenstra_2017.json
# 30    ../data/interim/article_dicts/Dondzilo_2019.json
# 34   ../data/interim/article_dicts/Van_Duijvenbode_...
# 36       ../data/interim/article_dicts/Linke_2017.json
# 37   ../data/interim/article_dicts/Schippers_2021.json
# 40   ../data/interim/article_dicts/Fleurkens_2018.json
# 43       ../data/interim/article_dicts/Rolle_2021.json
# 44       ../data/interim/article_dicts/Zhang_2018.json
# 45   ../data/interim/article_dicts/Brockmeyer_2015_...
# 47        ../data/interim/article_dicts/Phaf_2014.json
# 49     ../data/interim/article_dicts/Cousijn_2012.json
# 50        ../data/interim/article_dicts/Bach_2021.json
# 52     ../data/interim/article_dicts/Janssen_2015.json
# 56    ../data/interim/article_dicts/Reinecke_2012.json
# 58        ../data/interim/article_dicts/Kong_2015.json
# 64   ../data/interim/article_dicts/Heerebout_2013.json
# 70    ../data/interim/article_dicts/Garfield_2021.json
# 71       ../data/interim/article_dicts/Navas_2021.json
# 72   ../data/interim/article_dicts/Fernández-Teruel...
# 75      ../data/interim/article_dicts/TAYLOR_1961.json
# 76     ../data/interim/article_dicts/Asnaani_2014.json
# 79     ../data/interim/article_dicts/Amemori_2021.json
# 80       ../data/interim/article_dicts/Eisma_2015.json
# 83     ../data/interim/article_dicts/Cludius_2017.json
# 95     ../data/interim/article_dicts/Cousijn_2013.json
# 101      ../data/interim/article_dicts/Zhang_2019.json
# 111     ../data/interim/article_dicts/Karoly_2019.json
# 112  ../data/interim/article_dicts/Kakoschke_2017.json
# 117    ../data/interim/article_dicts/Voegtle_2021.json
# 123     ../data/interim/article_dicts/Barker_2019.json
# 125     ../data/interim/article_dicts/Oliver_2018.json
# 138   ../data/interim/article_dicts/Sofuoglu_2016.json
# 139    ../data/interim/article_dicts/Kahveci_2021.json
# 141      ../data/interim/article_dicts/Klein_2011.json
# 142      ../data/interim/article_dicts/Vogel_2019.json
# 143   ../data/interim/article_dicts/Tzavella_2021.json
# 144    ../data/interim/article_dicts/Tipples_2019.json
# 148        ../data/interim/article_dicts/Luo_2019.json
# 150  ../data/interim/article_dicts/Machulska_2020.json
# 151      ../data/interim/article_dicts/Najmi_2010.json
# 154    ../data/interim/article_dicts/Jacobus_2018.json
# 156   ../data/interim/article_dicts/Paslakis_2021.json
# 164     ../data/interim/article_dicts/Loijen_2020.json
# 165   ../data/interim/article_dicts/Verbeken_2018.json
# 167    ../data/interim/article_dicts/Cousijn_2014.json
# 168      ../data/interim/article_dicts/Boffo_2015.json
# 170  ../data/interim/article_dicts/Campanella_2016....
# 178      ../data/interim/article_dicts/Lukas_2021.json
# 179      ../data/interim/article_dicts/Lacey_2021.json
# 180    ../data/interim/article_dicts/Peeters_2020.json
# 181    ../data/interim/article_dicts/Roelofs_2009.json
# 184   ../data/interim/article_dicts/Keijsers_2021.json
# 185       ../data/interim/article_dicts/Hahn_2019.json
# 193  ../data/interim/article_dicts/Baquedano_2020.json
# 197       ../data/interim/article_dicts/Saga_2019.json
# 199   ../data/interim/article_dicts/Swinkels_2019.json
# 204  ../data/interim/article_dicts/Brambilla_2019.json
# 209   ../data/interim/article_dicts/Brignell_2009.json
# 210  ../data/interim/article_dicts/Sharbanee_2014.json
# 212  ../data/interim/article_dicts/Schoenmakers_200...
# 214   ../data/interim/article_dicts/Veenstra_2011.json
# 220      ../data/interim/article_dicts/Prior_2021.json
# 221    ../data/interim/article_dicts/Voncken_2012.json
# 222   ../data/interim/article_dicts/Anderson_2016.json
# 227   ../data/interim/article_dicts/De_Carli_2019.json
# 234   ../data/interim/article_dicts/Dapprich_2021.json
# 236      ../data/interim/article_dicts/Kemps_2013.json
# 237      ../data/interim/article_dicts/Boffo_2018.json
# 240  ../data/interim/article_dicts/Lobbestael_2016....
# 241    ../data/interim/article_dicts/Zhang_2018_1.json
# 242    ../data/interim/article_dicts/Tibboel_2015.json
# 246      ../data/interim/article_dicts/Radke_2017.json
# 250    ../data/interim/article_dicts/Manning_2020.json
# 253   ../data/interim/article_dicts/Maximino_2011.json
# 260     ../data/interim/article_dicts/Paulus_2017.json
# 262  ../data/interim/article_dicts/Korucuoglu_2014....
# 266      ../data/interim/article_dicts/Reddy_2016.json
# 267   ../data/interim/article_dicts/Williams_2016.json
# 268    ../data/interim/article_dicts/Cousijn_2015.json
# 271      ../data/interim/article_dicts/Leung_2017.json
# 272    ../data/interim/article_dicts/Clausen_2016.json
# 275       ../data/interim/article_dicts/Koch_2020.json
# 278      ../data/interim/article_dicts/Hoofs_2020.json
# 282      ../data/interim/article_dicts/Eberl_2013.json
# 284  ../data/interim/article_dicts/Groefsema_2020.json
# 286     ../data/interim/article_dicts/Watson_2012.json
# 291      ../data/interim/article_dicts/Rinck_2018.json
# 298     ../data/interim/article_dicts/Loijen_2018.json
# 304      ../data/interim/article_dicts/Lange_2008.json
# 309  ../data/interim/article_dicts/Snagowski_2015.json
# 311    ../data/interim/article_dicts/Manning_2019.json
# 312      ../data/interim/article_dicts/Meule_2019.json
# 313  ../data/interim/article_dicts/Batschelet_2020....
# 319  ../data/interim/article_dicts/van_Duijvenbode_...
# 324       ../data/interim/article_dicts/Mehl_2018.json
# 329  ../data/interim/article_dicts/Groefsema_2016.json
# 335   ../data/interim/article_dicts/Zorowitz_2019.json
# 336    ../data/interim/article_dicts/Zhang_2018_2.json
# 349     ../data/interim/article_dicts/Becker_2018.json
# 363     ../data/interim/article_dicts/Gordon_2019.json
# 364  ../data/interim/article_dicts/Shevorykin_2019....
# 368  ../data/interim/article_dicts/Melkonyan_2020.json
# 371    ../data/interim/article_dicts/Struijs_2018.json
# 376    ../data/interim/article_dicts/den_Uyl_2016.json
# 377    ../data/interim/article_dicts/Manning_2018.json
# 386  ../data/interim/article_dicts/Korucuoglu_2016....
# 387     ../data/interim/article_dicts/Loeber_2013.json
# 388    ../data/interim/article_dicts/Gladwin_2014.json
# 389      ../data/interim/article_dicts/Enter_2012.json
# 396  ../data/interim/article_dicts/Buades-Rotger_20...
# 398  ../data/interim/article_dicts/Kappelmann_2020....
# 405     ../data/interim/article_dicts/BAILEY_1952.json
# 406  ../data/interim/article_dicts/Machulska_2019.json
# 408      ../data/interim/article_dicts/Leehr_2016.json
# 412       ../data/interim/article_dicts/Woud_2016.json
# 414    ../data/interim/article_dicts/Peeters_2012.json
# 415    ../data/interim/article_dicts/Pieters_2014.json
# 416  ../data/interim/article_dicts/Brockmeyer_2019....
# 421    ../data/interim/article_dicts/Kyriazi_2020.json
# 422    ../data/interim/article_dicts/Laurens_2020.json
# 425        ../data/interim/article_dicts/Wen_2021.json
# 428  ../data/interim/article_dicts/Wittekind_2019_1...
# 429      ../data/interim/article_dicts/Zhang_2020.json
# 435  ../data/interim/article_dicts/Wittekind_2021.json
# 436   ../data/interim/article_dicts/Pedersen_2021.json
# 438      ../data/interim/article_dicts/Wiers_2015.json
# 440  ../data/interim/article_dicts/Wittekind_2015_1...
# 443  ../data/interim/article_dicts/van_Deursen_2013...
# 444     ../data/interim/article_dicts/Gentry_2016.json
# 449      ../data/interim/article_dicts/Preis_2021.json
# 455  ../data/interim/article_dicts/Boendermaker_201...
# 456     ../data/interim/article_dicts/Bryant_2020.json
# 459     ../data/interim/article_dicts/Giesen_2016.json
# 460      ../data/interim/article_dicts/Kemps_2020.json
# 466     ../data/interim/article_dicts/Leeman_2014.json
# 473    ../data/interim/article_dicts/Smith_2021_1.json
# 476   ../data/interim/article_dicts/McNamara_2021.json
# 484         ../data/interim/article_dicts/Du_2021.json
# 487  ../data/interim/article_dicts/Havermans_2011.json
# 489    ../data/interim/article_dicts/Detandt_2017.json
# 494     ../data/interim/article_dicts/Degnan_2011.json
# 495      ../data/interim/article_dicts/Szeto_2019.json
# 500      ../data/interim/article_dicts/Enter_2014.json
# 501        ../data/interim/article_dicts/Chu_2020.json
# 504  ../data/interim/article_dicts/Suffoletto_2020....
# 506      ../data/interim/article_dicts/Smith_2021.json
# 508      ../data/interim/article_dicts/Field_2006.json
# 509      ../data/interim/article_dicts/Eberl_2014.json
# 510       ../data/interim/article_dicts/Külz_2014.json
# 511        ../data/interim/article_dicts/Wen_2020.json
# 514   ../data/interim/article_dicts/Hinzmann_2020.json
# 520     ../data/interim/article_dicts/Bollen_2021.json
# 532   ../data/interim/article_dicts/Klaassen_2021.json
# 534       ../data/interim/article_dicts/Bach_2014.json
# 537  ../data/interim/article_dicts/Kakoschke_2015.json
#
#                                                   note
# 0                               Only a study protocol.
# 1                                               review
# 7                                         animal study
# 12                                   borderline; faces
# 13   anxiety, mentiones that rinkck and becker are ...
# 14   reports retest reliability of other tasks but ...
# 15                         1961 study, probably no AAT
# 16                                          pedophilia
# 18   mentions low reliability in discussion; intere...
# 19                                           old study
# 24                                              review
# 29   title should be: "Drawn to danger: trait anger...
# 30                                  not uncertain: SRT
# 34   mention problem with reliability ("Remain uncl...
# 36   report retest reliability of other questionnai...
# 37                               crazy high split-half
# 40                                          depression
# 43                          drift diffusion modelling!
# 44   smartphone based interviention;interesting; do...
# 45   seems to mention that there is no data availab...
# 47                               meta-analysis; review
# 49   mentions that more studies are needed to test ...
# 50            very interesting review on cross-species
# 52   latent growth curve; does not include task bec...
# 56           mentions reinecke and calls task reliable
# 58   mentions that reliability hasn't been investig...
# 64                                         interesting
# 70                                       protocol only
# 71                                              review
# 72                                          commentary
# 75                                                 old
# 76   mentions reinecke but does not check reliabili...
# 79                                         interesting
# 80                                   mentions reinecke
# 83   conference; mentions thta reliabiliy should be...
# 95   mentions non-results could be caused by reliab...
# 101                                             review
# 111  mentions the reliability concers of AAT (ROdeb...
# 112                                             review
# 117           mention that reliability is under debate
# 123                                             review
# 125                                 calls AAT reliable
# 138                                 interesting review
# 139               not sure whether retest was analyzed
# 141  report retest reliability for questionnaire bu...
# 142                         mentions reliability study
# 143  interesting; explicitely discuss reliability p...
# 144                                    interesting ddf
# 148           calls chronbach alpha of .49 fairly high
# 150                                     study protocol
# 151                                       joystick aat
# 154  mentions that retest reliability is still unde...
# 156                                             review
# 164       review; interesting reliability distinctions
# 165                                   only feasibility
# 167                  discusses reliability extensively
# 168                                     study protocol
# 170                                         commentary
# 178                    gamified task; smartphone based
# 179                                          important
# 180                                       interesting!
# 181                             calls the AAT reliable
# 184                                             review
# 185             looks like they could have done retest
# 193                              interesting eeg study
# 197                                        interesting
# 199  joystick AAT; interesting; mentions that relia...
# 204                                        interesting
# 209                                        manikin SRC
# 210              interesting; mentions aat is reliable
# 212                                        interesting
# 214                               mentions reliability
# 220                                  feasibility study
# 221  mentions that retest reliability is not establ...
# 222                                        interesting
# 227                                        interesting
# 234         discuss moderate reliability as limitation
# 236                                       approach iat
# 237         mention retest for other tasks but not aat
# 240                          discusses bad reliability
# 241                                             review
# 242                                             review
# 246                                  fMRI joystick AAT
# 250                                    interesting app
# 253                                   very interesting
# 260  interesting; mention importance of studying re...
# 262                                   interesting; eeg
# 266                    not sure if they did split half
# 267                                     interesting!!!
# 268                        not sure if they did retest
# 271                              meta-analysis; review
# 272                 mentions reliability as limitation
# 275                   mentions reliability as strength
# 278  discuss reliability extensively but do not see...
# 282  mention retest reliability of other questionna...
# 284                                        interesting
# 286         review important mentions AAT reliability!
# 291  The internal consistency of the scores was low...
# 298                                       feasibilitiy
# 304  joystick AAT; calls aat reliable but does not ...
# 309                                           joystick
# 311                                        feasibility
# 312                extensive discussion of reliability
# 313                                             review
# 319                    calls cogniitev biases reliable
# 324                         not sure if they report it
# 329               it seems they could have done retest
# 335      very interest; model based approach avoidance
# 336           interesting review on gamefied cbm tasks
# 349                                         commentary
# 363                                     study protocol
# 364                                    interesting EEG
# 368                           uses serkons package! :)
# 371                                        interesting
# 376                                        interesting
# 377                                     study protocol
# 386                                    interesting eeg
# 387                extremely relevant for food study!!
# 388                                   very interesting
# 389              very interesting!; calls aat reliable
# 396  explicitely mentions the lack of reliability s...
# 398  calls reineckes results "sufficient retest rel...
# 405                                        interesting
# 406                                      training only
# 408                                        interesting
# 412  mention reliability but do not seem to measure...
# 414  seems like this is a simple push minus pull di...
# 415                                                src
# 416           mention doubt in reliability of the AAT
# 421                                        interesting
# 422               interesting aat app (no measurement)
# 425    specifically mention low reliability as problem
# 428                        this is a withdrawal notice
# 429    mentions reliability issues (cites Zhang, 2019)
# 435  discusses reliability extensively uses serkan'...
# 436  fMRI joystick AAT; interesting ddm; I think th...
# 438                                             review
# 440  mentions reliability of the task and mentions ...
# 443                                           protocol
# 444                                        interesting
# 449      mentions bad reliability (kersbergen; lender)
# 455                                       gamification
# 456                                            review?
# 459                                            review?
# 460                                             review
# 466                                             review
# 473  SRC, quite different from AAT; one-year follow...
# 476                         interesting; priming doses
# 484                                        interesting
# 487                                                src
# 489                                 seems like go/nogo
# 494                             interesting baby study
# 495                                             stroop
# 500                             calls the AAT reliable
# 501                                       keyboard aat
# 504  longitudinal aat alcohol study!; seems like in...
# 506                               computational model!
# 508                                                src
# 509   checks how many sessions are needed for training
# 510                                           protocol
# 511                mentions unsatisfactory reliability
# 514  did both manikin SRC and joystick AAT; only re...
# 520  interesting eye tracking study; should be in g...
# 532               very interesting on aat and freezing
# 534                            potentially interesting
# 537          interesting on aat and inhibitory control
